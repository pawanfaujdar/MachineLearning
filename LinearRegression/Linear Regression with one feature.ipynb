# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data=np.loadtxt("data.csv",delimiter=",")

# %%
data.shape
# Out:
# (100, 2)

# %%
x=data[:,0]
y=data[:,1]

# %%
x.shape,y.shape
# Out:
# ((100,), (100,))

# %%
x=x.reshape(-1,1)
x.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
alg=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
alg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Method 1:

# %%
y_pred=alg.predict(x_test)
y_pred
# Out:
# array([83.90794352, 75.58322086, 89.5552157 , 80.92141974, 66.75727066,
#        69.08304295, 67.01731821, 64.90394929, 75.58310682, 74.16677711,
#        63.04780693, 99.23689958, 81.89507412, 85.05666178, 59.80811107,
#        77.10233815, 70.75599657, 76.59545217, 85.05140222, 71.59074994,
#        65.92464468, 77.30900845, 70.74854471, 79.02510779, 50.93578366])

# %% [markdown]
# # Method 2:

# %%
m=alg.coef_[0]

# %%
c=alg.intercept_

# %%
x_line=np.arange(30,70,0.1)
y_line=m*x_line+c

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x_line,y_line,"r")
train_1D=x_train.reshape(75)
test_1D=x_test.reshape(25)
plt.scatter(train_1D,y_train,c="green")
plt.scatter(test_1D,y_test,c="blue")
plt.show()

# %%
alg.score(x_test,y_test)
# Out:
# 0.38453176323417004

# %%
alg.score(x_train,y_train)
# Out:
# 0.6514136253148364
