# %%
import numpy as np

# %%
train_data=np.loadtxt("0000000000002329_training_diabetes_x_y_train.csv",delimiter=",")
test_data=np.loadtxt("0000000000002329_test_diabetes_x_test.csv",delimiter=",")

# %%
train_data.shape, test_data.shape
# Out:
# ((331, 11), (111, 10))

# %%
from sklearn.linear_model import LinearRegression

# %%
alg=LinearRegression()

# %%
alg.fit(train_data[:,0:10],train_data[:,10])
# Out:
# LinearRegression()

# %%
test_pred_data=alg.predict(test_data)

# %%
alg.score(test_data,test_pred_data)
# Out:
# 1.0
