# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # Creating Model:

# %%
model=Sequential()

# %% [markdown]
# # Defining Architechture:

# %%
layer1=Dense(units=32,activation="relu", input_dim=30) #input layer
model.add(layer1)
model.add(Dense(units=16,activation="relu")) #hidden layer
model.add(Dense(units=1,activation="sigmoid")) #output layer

# %% [markdown]
# # Compling the Model:

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# # Fitting Training Data:

# %%
from sklearn import datasets
cancer=datasets.load_breast_cancer()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(cancer.data,cancer.target, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
model.fit(x_train,y_train, epochs=20,batch_size=50)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6424 - accuracy: 0.6198
# Epoch 2/20
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.9011
# Epoch 3/20
# 10/10 [==============================] - 0s 733us/step - loss: 0.3397 - accuracy: 0.9341
# Epoch 4/20
# 10/10 [==============================] - 0s 774us/step - loss: 0.2667 - accuracy: 0.9451
# Epoch 5/20
# 10/10 [==============================] - 0s 878us/step - loss: 0.2220 - accuracy: 0.9538
# Epoch 6/20
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1896 - accuracy: 0.9582
# Epoch 7/20
# 10/10 [==============================] - 0s 685us/step - loss: 0.1655 - accuracy: 0.9626
# Epoch 8/20
# 10/10 [==============================] - 0s 722us/step - loss: 0.1471 - accuracy: 0.9648
# Epoch 9/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1318 - accuracy: 0.9670
# Epoch 10/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.9692
# Epoch 11/20
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1096 - accuracy: 0.9714
# Epoch 12/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.9780
# Epoch 13/20
# 10/10 [==============================] - 0s 915us/step - loss: 0.0944 - accuracy: 0.9802
# Epoch 14/20
# 10/10 [==============================] - 0s 717us/step - loss: 0.0886 - accuracy: 0.9802
# Epoch 15/20
# 10/10 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.98 - 0s 982us/step - loss: 0.0839 - accuracy: 0.9846
# Epoch 16/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9846
# Epoch 17/20
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9846
# Epoch 18/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9868
# Epoch 19/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9868
# Epoch 20/20
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 0.9890

# %% [markdown]
# # Evaluations & Predictions:

# %%
predictions=model.predict(x_test)
predictions
# Out:
# array([[1.70513988e-02],
#        [9.69849110e-01],
#        [9.98343766e-01],
#        [9.88972425e-01],
#        [9.99420643e-01],
#        [9.95408058e-01],
#        [9.90768909e-01],
#        [9.98734593e-01],
#        [9.99924242e-01],
#        [9.99831796e-01],
#        [5.98048568e-01],
#        [7.91912735e-01],
#        [9.99701142e-01],
#        [1.76411867e-01],
#        [4.39981371e-01],
#        [2.70635486e-02],
#        [9.83549714e-01],
#        [1.07774138e-03],
#        [9.18266177e-03],
#        [5.61272318e-05],
#        [1.34975016e-02],
#        [2.78083384e-02],
#        [9.72841263e-01],
#        [9.97047901e-01],
#        [3.64378095e-03],
#        [9.99312162e-01],
#        [9.99933898e-01],
#        [9.10708308e-03],
#        [9.98368740e-01],
#        [1.61746144e-03],
#        [9.99883771e-01],
#        [1.81135833e-02],
#        [8.62158179e-01],
#        [1.93678439e-02],
#        [9.99989212e-01],
#        [2.21037269e-02],
#        [9.91646647e-01],
#        [1.00646615e-02],
#        [9.88022566e-01],
#        [4.08821404e-02],
#        [2.08574831e-01],
#        [9.99785900e-01],
#        [2.20480591e-01],
#        [9.99858975e-01],
#        [9.59496319e-01],
#        [1.48177147e-04],
#        [9.99996066e-01],
#        [9.82965708e-01],
#        [9.98531699e-01],
#        [1.46004558e-03],
#        [2.91019678e-04],
#        [6.91052675e-02],
#        [6.26018643e-03],
#        [9.97914910e-01],
#        [9.85205650e-01],
#        [9.99588072e-01],
#        [9.97876167e-01],
#        [9.98570085e-01],
#        [9.96480525e-01],
#        [1.88120684e-05],
#        [5.73046505e-02],
#        [7.73277581e-02],
#        [9.99594867e-01],
#        [9.92787659e-01],
#        [2.29352713e-03],
#        [9.55719352e-01],
#        [3.85337415e-08],
#        [3.20404768e-04],
#        [6.68972731e-04],
#        [9.97919142e-01],
#        [6.98419452e-01],
#        [1.10936165e-03],
#        [9.97473240e-01],
#        [5.10863602e-01],
#        [7.26670027e-04],
#        [9.83312011e-01],
#        [9.99767303e-01],
#        [8.04129004e-01],
#        [9.99784231e-01],
#        [9.99858439e-01],
#        [6.38899505e-02],
#        [8.68285611e-07],
#        [1.80435181e-03],
#        [9.99822795e-01],
#        [1.02326930e-01],
#        [9.98915434e-01],
#        [9.99868751e-01],
#        [9.99971867e-01],
#        [1.00359619e-02],
#        [5.68589599e-07],
#        [9.99897480e-01],
#        [6.88183725e-01],
#        [4.62259203e-01],
#        [2.32517719e-04],
#        [9.98319268e-01],
#        [9.96289134e-01],
#        [4.62085009e-04],
#        [9.80851054e-01],
#        [9.93312240e-01],
#        [9.94566083e-01],
#        [9.99788046e-01],
#        [9.95614827e-01],
#        [9.88592982e-01],
#        [6.12583756e-01],
#        [5.37529588e-03],
#        [9.46645081e-01],
#        [3.12477350e-04],
#        [5.92308283e-01],
#        [7.66984582e-01],
#        [7.92809367e-01],
#        [9.63548899e-01],
#        [2.36991048e-03],
#        [5.83267212e-03],
#        [7.95274794e-01]], dtype=float32)

# %%
score=model.evaluate(x_test,y_test)
score  #loss, accuracy
# Out:
# 4/4 [==============================] - 0s 0s/step - loss: 0.1098 - accuracy: 0.9386
# [0.10983676463365555, 0.9385964870452881]
