# %%
import numpy as np

# %%
train_data=np.loadtxt("0000000000002417_training_boston_x_y_train.csv",delimiter=",")
test_data=np.loadtxt("0000000000002417_test_boston_x_test.csv",delimiter=",")

# %%
one_train=np.ones(len(train_data))
one_test=np.ones(len(test_data))
train_data.shape,test_data.shape
# Out:
# ((379, 14), (127, 13))

# %%
y_train=train_data[:,13]
y_train.shape
# Out:
# (379,)

# %%
x_train=train_data[:,0:13]
x_train.shape
# Out:
# (379, 13)

# %%
x_train=np.column_stack((x_train,one_train))
x_test=np.column_stack((test_data,one_test))
x_train.shape,x_test.shape
# Out:
# ((379, 14), (127, 14))

# %%
def step_gradient(x,y,learning_rate,m):
    m_slope=np.zeros(x.shape[1])
    N=len(x)
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            m_slope[j]+=(-2/N)*(y[i]-(m.dot(x[i,:])))*x[i,j]
    new_m=m-learning_rate*m_slope 
    return new_m

# %%
def cost(x,y,m):
    total_cost=0
    N=x.shape[0]
    for i in range(N):
        total_cost+=(1/N)*((y[i]-m.dot(x[i,:]))**2)
    return total_cost

# %%
def gd(x,y,learning_rate,num_iterations):
    m=np.zeros(x.shape[1])
    for i in range(num_iterations):
        m=step_gradient(x,y,learning_rate,m)
        print(i,"cost:",cost(x,y,m))
    return m

# %%
def run():
    learning_rate=0.1
    num_iterations=100
    m=gd(x_train,y_train,learning_rate,num_iterations)
    return m

# %%
m=run()
# Out:
# 0 cost: 374.24035597919686
# 1 cost: 245.37909656079904
# 2 cost: 165.10614192173665
# 3 cost: 114.49508621191686
# 4 cost: 82.43432664281795
# 5 cost: 62.041704688310915
# 6 cost: 49.0154746660482
# 7 cost: 40.65519326019772
# 8 cost: 35.259728350675914
# 9 cost: 31.754121492629714
# 10 cost: 29.457161634001743
# 11 cost: 27.93600702214453
# 12 cost: 26.914922412896377
# 13 cost: 26.217802951980172
# 14 cost: 25.731872822963105
# 15 cost: 25.384699117718043
# 16 cost: 25.129603525591076
# 17 cost: 24.936384410518777
# 18 cost: 24.78540479203736
# 19 cost: 24.663818221907476
# 20 cost: 24.563155143621437
# 21 cost: 24.477776518190062
# 22 cost: 24.403881200700226
# 23 cost: 24.3388674348962
# 24 cost: 24.280921148348458
# 25 cost: 24.228749732407817
# 26 cost: 24.181409300585184
# 27 cost: 24.138192120101174
# 28 cost: 24.09855285948924
# 29 cost: 24.06205993819115
