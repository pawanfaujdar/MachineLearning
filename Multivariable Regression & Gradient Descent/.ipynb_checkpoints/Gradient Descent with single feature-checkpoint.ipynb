# %%
import numpy as np

# %%
# def step_gradient(points,learning_rate,m,c):
#     m_slope,c_slope=0,0
#     N=len(points)
#     for i in range(N):
#         x=points[i,0]
#         y=points[i,1]
#         m_slope+=(-2/N)*(y-m*x-c)*x
#         c_slope+=(-2/N)*(y-m*x-c)
#     new_m=m-learning_rate*m_slope
#     new_c=c-learning_rate*c_slope
#     return new_m,new_c

# %%
def step_gradient(points,learning_rate,m,c):
    m_slope,c_slope=0,0
    N=len(points)
    x=points[:,0]
    y=points[:,1]
    m_slope=((-2/N)*(y-m*x-c)*x).sum()
    c_slope=((-2/N)*(y-m*x-c)).sum()
    new_m=m-learning_rate*m_slope
    new_c=c-learning_rate*c_slope
    return new_m,new_c

# %%
# def cost(points,m,c):
#     total_cost=0
#     N=len(points)
#     for i in range(N):
#         x=points[i,0]
#         y=points[i,1]
#         total_cost+=(1/N)*((y-m*x-c)**2)
#     return total_cost

# %%
def cost(points,m,c):
    total_cost=0
    N=len(points)
    x=points[:,0]
    y=points[:,1]
    total_cost=(1/N)*((y-m*x-c)**2).sum()
    return total_cost

# %%
def gd(points,learning_rate,num_iterations):
    m,c=0,0
    for i in range(num_iterations):
        m,c=step_gradient(points,learning_rate,m,c)
        print(i,"cost",cost(points,m,c))
    return m,c

# %%
def run():
    data=np.loadtxt("data.csv",delimiter=",")
    learning_rate=0.0001
    num_iterations=10
    m,c=gd(data,learning_rate,num_iterations)
    print(m,c)

# %%
run()
# Out:
# 0 cost 1484.5865574086483
# 1 cost 457.8542575737669
# 2 cost 199.50998572553866
# 3 cost 134.50591058200536
# 4 cost 118.14969342239947
# 5 cost 114.03414906038152
# 6 cost 112.99857731713662
# 7 cost 112.73798187568465
# 8 cost 112.67238435909101
# 9 cost 112.65585181499748
# 1.47741737554838 0.029639347874732373
